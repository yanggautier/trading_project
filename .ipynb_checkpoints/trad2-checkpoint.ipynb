# %%
import pymongo
import pandas as pd
import numpy as np
from datetime import date
from dateutil import parser as date_parser
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [16, 9]

# %%
from pymongo import MongoClient
client = MongoClient('localhost', 27017)
db = client.trading
symbol = "GOOGL"
collection = db[symbol]

# %%
df = pd.DataFrame(list(collection.find()))

# %%
df
# Out:
#                            _id                      date     open     high  \
# 0     5f6c50202c3f6107f05464e4  2020-09-23T00:00:00.000Z  1452.09  1453.08
# 1     5f6c50202c3f6107f05464e5  2020-09-22T00:00:00.000Z  1450.32  1463.97
# 2     5f6c50202c3f6107f05464e6  2020-09-21T00:00:00.000Z  1431.62  1440.06
# 3     5f6c50202c3f6107f05464e7  2020-09-18T00:00:00.000Z  1488.30  1495.20
# 4     5f6c50202c3f6107f05464e8  2020-09-17T00:00:00.000Z  1485.81  1498.66
# ...                        ...                       ...      ...      ...
# 4048  5f6c50202c3f6107f05474b4  2004-08-25T00:00:00.000Z   104.76   108.00
# 4049  5f6c50202c3f6107f05474b5  2004-08-24T00:00:00.000Z   111.24   111.60
# 4050  5f6c50202c3f6107f05474b6  2004-08-23T00:00:00.000Z   110.76   113.48
# 4051  5f6c50202c3f6107f05474b7  2004-08-20T00:00:00.000Z   101.01   109.08
# 4052  5f6c50202c3f6107f05474b8  2004-08-19T00:00:00.000Z   100.01   104.06
#
#            low     close      volume symbol
# 0     1402.680  1409.390   1886299.0  GOOGL
# 1     1429.495  1459.820   1697542.0  GOOGL
# 2     1402.680  1430.140   2845405.0  GOOGL
# 3     1431.620  1451.090   3152788.0  GOOGL
# 4     1462.460  1487.040   2000356.0  GOOGL
# ...        ...       ...         ...    ...
# 4048   103.880   106.000   9188600.0  GOOGL
# 4049   103.570   104.870  15247300.0  GOOGL
# 4050   109.050   109.400  18256100.0  GOOGL
# 4051   100.500   108.310  22834300.0  GOOGL
# 4052    95.960   100.335  44659000.0  GOOGL
#
# [4053 rows x 8 columns]

# %%
df2 = df[['date', 'symbol', 'open', 'close', 'high', 'low', 'volume']]

# %%
df2['date'] = pd.to_datetime(df2['date']).dt.tz_localize(None)
# Out:
# <ipython-input-8-6ebc0551d850>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['date'] = pd.to_datetime(df2['date']).dt.tz_localize(None)

# %%
df2
# Out:
#            date symbol     open     close     high       low      volume
# 0    2020-09-23  GOOGL  1452.09  1409.390  1453.08  1402.680   1886299.0
# 1    2020-09-22  GOOGL  1450.32  1459.820  1463.97  1429.495   1697542.0
# 2    2020-09-21  GOOGL  1431.62  1430.140  1440.06  1402.680   2845405.0
# 3    2020-09-18  GOOGL  1488.30  1451.090  1495.20  1431.620   3152788.0
# 4    2020-09-17  GOOGL  1485.81  1487.040  1498.66  1462.460   2000356.0
# ...         ...    ...      ...       ...      ...       ...         ...
# 4048 2004-08-25  GOOGL   104.76   106.000   108.00   103.880   9188600.0
# 4049 2004-08-24  GOOGL   111.24   104.870   111.60   103.570  15247300.0
# 4050 2004-08-23  GOOGL   110.76   109.400   113.48   109.050  18256100.0
# 4051 2004-08-20  GOOGL   101.01   108.310   109.08   100.500  22834300.0
# 4052 2004-08-19  GOOGL   100.01   100.335   104.06    95.960  44659000.0
#
# [4053 rows x 7 columns]

# %%
df3 = df2[['date', 'close']]

# %%
df3 = df3.resample('1440Min', on='date').first().drop('date', 1).reset_index()

# %%
df3 = df3.fillna(method='ffill')

# %%
predict_nb_day = 14

# %%
date = df3[-1:]['date']
for _ in range(predict_nb_day):
    dayplus = {"date": date + pd.DateOffset(1), "close":np.nan}
    df3 = df3.append(pd.DataFrame(dayplus))

# %%
df4 = df3.set_index('date')

# %%
df4[-5*predict_nb_day:]
# Out:
#               close
# date
# 2020-07-31  1487.95
# 2020-08-01  1487.95
# 2020-08-02  1487.95
# 2020-08-03  1482.76
# 2020-08-04  1473.30
# ...             ...
# 2020-09-25      NaN
# 2020-09-25      NaN
# 2020-09-25      NaN
# 2020-09-25      NaN
# 2020-09-25      NaN
#
# [70 rows x 1 columns]

# %%
df4.plot(figsize=(15,10))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train_len = int((len(df4)-predict_nb_day)/10*9)
val_len = len(df4) - train_len -predict_nb_day

X_train = scaler.fit_transform(df4[['close']][0:train_len].values)
X_val = scaler.transform(df4[['close']][train_len:-predict_nb_day].values)
X_test = scaler.transform(df4[['close']][-5*predict_nb_day:].values)

# %%
X_test
# Out:
# array([[1.17077327],
#        [1.17077327],
#        [1.17077327],
#        [1.16639533],
#        [1.15841551],
#        [1.16329956],
#        [1.18511333],
#        [1.17956288],
#        [1.17956288],
#        [1.17956288],
#        [1.1782554 ],
#        [1.16452269],
#        [1.18704502],
#        [1.19498267],
#        [1.1848434 ],
#        [1.1848434 ],
#        [1.1848434 ],
#        [1.19463682],
#        [1.22799011],
#        [1.21856785],
#        [1.24525724],
#        [1.24468363],
#        [1.24468363],
#        [1.24468363],
#        [1.25276468],
#        [1.27022581],
#        [1.30251626],
#        [1.28934871],
#        [1.29855165],
#        [1.29855165],
#        [1.29855165],
#        [1.29020068],
#        [1.31175295],
#        [1.36431349],
#        [1.29018381],
#        [1.24944116],
#        [1.24944116],
#        [1.24944116],
#        [1.24944116],
#        [1.20084522],
#        [1.22077791],
#        [1.20291188],
#        [1.19423192],
#        [1.19423192],
#        [1.19423192],
#        [1.18838624],
#        [1.21056272],
#        [1.19113615],
#        [1.17000565],
#        [1.13968064],
#        [1.13968064],
#        [1.13968064],
#        [1.12200862],
#        [1.14704468],
#        [1.10450531],
#        [1.10450531],
#        [       nan],
#        [       nan],
#        [       nan],
#        [       nan],
#        [       nan],
#        [       nan],
#        [       nan],
#        [       nan],
#        [       nan],
#        [       nan],
#        [       nan],
#        [       nan],
#        [       nan],
#        [       nan]])

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
X_train, y_train = split_sequence(X_train, 12)
X_val, y_val = split_sequence(X_val, 12)
X_test, y_test = split_sequence(X_test, 12)

# %%
n_features=1
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

# %%
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout

model = Sequential([
    LSTM(50, activation="relu", input_shape=X_train.shape[1:]), # or (X_train.shape[1], 1) or (n_steps, n_features)
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping_cb = EarlyStopping(monitor='val_loss', patience=10,
                          restore_best_weights=True)

# %%
history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_val, y_val),
                    batch_size = 32,
                    callbacks=early_stopping_cb)
# Out:
# Epoch 1/100
# 165/165 [==============================] - 1s 8ms/step - loss: 0.0149 - val_loss: 0.0033
# Epoch 2/100
# 165/165 [==============================] - 1s 7ms/step - loss: 3.3266e-04 - val_loss: 0.0021
# Epoch 3/100
# 165/165 [==============================] - 1s 7ms/step - loss: 3.0293e-04 - val_loss: 0.0011
# Epoch 4/100
# 165/165 [==============================] - 1s 8ms/step - loss: 2.7308e-04 - val_loss: 0.0011
# Epoch 5/100
# 165/165 [==============================] - 1s 8ms/step - loss: 2.4644e-04 - val_loss: 7.1826e-04
# Epoch 6/100
# 165/165 [==============================] - 1s 8ms/step - loss: 2.2595e-04 - val_loss: 6.9127e-04
# Epoch 7/100
# 165/165 [==============================] - 1s 8ms/step - loss: 2.2276e-04 - val_loss: 7.3672e-04
# Epoch 8/100
# 165/165 [==============================] - 1s 7ms/step - loss: 2.1491e-04 - val_loss: 4.9263e-04
# Epoch 9/100
# 165/165 [==============================] - 1s 6ms/step - loss: 2.0740e-04 - val_loss: 5.2280e-04
# Epoch 10/100
# 165/165 [==============================] - 1s 6ms/step - loss: 1.9866e-04 - val_loss: 4.8253e-04
# Epoch 11/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.8856e-04 - val_loss: 4.8211e-04
# Epoch 12/100
# 165/165 [==============================] - 1s 9ms/step - loss: 1.9917e-04 - val_loss: 4.5318e-04
# Epoch 13/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.9157e-04 - val_loss: 4.7070e-04
# Epoch 14/100
# 165/165 [==============================] - 1s 8ms/step - loss: 1.8023e-04 - val_loss: 3.8790e-04
# Epoch 15/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.7399e-04 - val_loss: 4.4788e-04
# Epoch 16/100
# 165/165 [==============================] - 1s 8ms/step - loss: 1.7180e-04 - val_loss: 3.6937e-04
# Epoch 17/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.7997e-04 - val_loss: 4.2548e-04
# Epoch 18/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.5518e-04 - val_loss: 3.6952e-04
# Epoch 19/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.7715e-04 - val_loss: 3.7542e-04
# Epoch 20/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.6702e-04 - val_loss: 6.9459e-04
# Epoch 21/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.6219e-04 - val_loss: 3.5447e-04
# Epoch 22/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.4952e-04 - val_loss: 4.5285e-04
# Epoch 23/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.5505e-04 - val_loss: 3.9893e-04
# Epoch 24/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.5344e-04 - val_loss: 3.9991e-04
# Epoch 25/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.4254e-04 - val_loss: 0.0015
# Epoch 26/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.3683e-04 - val_loss: 3.9833e-04
# Epoch 27/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.5444e-04 - val_loss: 3.4711e-04
# Epoch 28/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.4723e-04 - val_loss: 4.1597e-04
# Epoch 29/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.3883e-04 - val_loss: 3.5144e-04
# Epoch 30/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.3623e-04 - val_loss: 3.4914e-04
# Epoch 31/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.3378e-04 - val_loss: 3.5572e-04
# Epoch 32/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.3390e-04 - val_loss: 3.7179e-04
# Epoch 33/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.2743e-04 - val_loss: 3.4945e-04
# Epoch 34/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.3205e-04 - val_loss: 4.1348e-04
# Epoch 35/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.3080e-04 - val_loss: 3.4827e-04
# Epoch 36/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.3751e-04 - val_loss: 3.4542e-04
# Epoch 37/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.1887e-04 - val_loss: 3.6730e-04
# Epoch 38/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.2519e-04 - val_loss: 4.3636e-04
# Epoch 39/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.3103e-04 - val_loss: 4.2511e-04
# Epoch 40/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.2604e-04 - val_loss: 4.0863e-04
# Epoch 41/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.2593e-04 - val_loss: 3.7058e-04
# Epoch 42/100
# 165/165 [==============================] - 1s 8ms/step - loss: 1.2626e-04 - val_loss: 4.0507e-04
# Epoch 43/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.2135e-04 - val_loss: 3.6014e-04
# Epoch 44/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.2569e-04 - val_loss: 3.9622e-04
# Epoch 45/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.2769e-04 - val_loss: 3.9675e-04
# Epoch 46/100
# 165/165 [==============================] - 1s 7ms/step - loss: 1.1709e-04 - val_loss: 3.7093e-04

# %%
mse_val = model.evaluate(X_val, y_val)
# Out:
# 19/19 [==============================] - 0s 3ms/step - loss: 3.4542e-04

# %%
rmse = np.sqrt(mse_val)
print(rmse)
# Out:
# 0.018585461895049935

# %%
mse_test = model.evaluate(X_val, y_val)
# Out:
# 19/19 [==============================] - 0s 4ms/step - loss: 3.4542e-04

# %%
predicted_close = model.predict(X_test)
predicted_close = scaler.inverse_transform(predicted_close)

# %%
prediction = pd.Series(predicted_close[-5*predict_nb_day-12:].reshape(-1), index = df4['close'].iloc[-5*predict_nb_day-12:].index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-4d98cc58d437> in <module>
# ----> 1 prediction = pd.Series(predicted_close[-5*predict_nb_day:].reshape(-1), index = df4['close'].iloc[-5*predict_nb_day:].index)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     289                 try:
#     290                     if len(index) != len(data):
# --> 291                         raise ValueError(
#     292                             f"Length of passed values is {len(data)}, "
#     293                             f"index implies {len(index)}."
#
# ValueError: Length of passed values is 58, index implies 70.

# %%
plt.plot(df4['close'][-365:], color = 'r', label = 'Real Stock')
plt.plot(prediction, color = 'b', label = 'Predicted Stock')
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Close Stock')
plt.legend()
plt.show()

# %%
predict_stock = prediction[-1]

# %%
last_stock = df4.iloc[-2]['close']

# %%
change_by_day = ((predict_stock) - last_stock)/last_stock
change_by_day
# Out:
# 0.008342320442044004

# %%
if(change_by_day > 0.05):
    print("You should buy")
elif (change_by_day < -0.05):
    print("Alerte, you should to sell")

# %%
from pygooglenews import GoogleNews
import pprint
gn = GoogleNews()
top = gn.top_news()
# gn = GoogleNews(lang = 'cn', country = 'CN')
# top = gn.top_news()
# business = gn.topic_headlines('BUSINESS')
search = gn.search(symbol, when = '1d')
entries = search['entries']

# %%
data = pd.DataFrame(columns = ['Author', 'Date', 'Title', 'Link'])

# %%
for entrie in entries :
    data = data.append(pd.Series({'Author': entrie.source.title, \
                           'Date': date_parser.parse(entrie.published),\
                           'Title': entrie.title, \
                           'Link': entrie.link \
                          }), \
                ignore_index=True)

# %%
data["Author"].unique()
# Out:
# array(['CFDTrading', 'Benzinga', 'The Motley Fool', 'Motley Fool',
#        'Seeking Alpha', 'Metro US', 'InvestorPlace',
#        'Chicago Business Journal', 'Nasdaq', 'Yahoo News',
#        'Yahoo Finance UK', 'Dividend Investor', 'Yahoo Sports',
#        'Investors Chronicle', "Barron's", 'Stock Investor',
#        'Yahoo News Canada', 'U.S News & World Report Money', 'RealMoney',
#        'India Today', 'TheStreet', 'MarketWatch', 'Brinkwire', 'Forbes',
#        'Nintendo-Power', 'GuruFocus.com', 'Reuters', 'Armenian Reporter',
#        'BOV News'], dtype=object)

# %%
data
# Out:
#                Author                       Date  \
# 0          CFDTrading  2020-09-23 11:22:00+00:00
# 1            Benzinga  2020-09-24 08:09:49+00:00
# 2     The Motley Fool  2020-09-23 11:28:00+00:00
# 3         Motley Fool  2020-09-23 15:37:00+00:00
# 4       Seeking Alpha  2020-09-24 08:45:00+00:00
# ..                ...                        ...
# 61             Nasdaq  2020-09-23 15:10:00+00:00
# 62             Nasdaq  2020-09-23 14:47:00+00:00
# 63             Nasdaq  2020-09-23 10:03:00+00:00
# 64  Armenian Reporter  2020-09-23 16:51:00+00:00
# 65           BOV News  2020-09-23 15:09:00+00:00
#
#                                                 Title  \
# 0   Alphabet Inc (GOOGL) 4 Day Down Streak Snapped...
# 1   Google Maps Adds Feature To Identify COVID-19 ...
# 2   Is Google-Backed Telemedicine Stock Amwell a B...
# 3   Google Antitrust Lawsuit to Narrowly Focus on ...
# 4   YouTube expands fact-checking, Facebook readie...
# ..                                                ...
# 61  Why Should You Bet On Cash-Like ETFs Ahead of ...
# 62  bluebird-Bristol Myers' CAR T Cell Therapy BLA...
# 63  3 Little-Known Social Security Facts That Coul...
# 64  Walmart is using drones to deliver COVID-19 te...
# 65  Reaping The Rewards Of An Adapted Business Str...
#
#                                                  Link
# 0   https://www.cfdtrading.com/alphabet-inc-googl-...
# 1   https://www.benzinga.com/news/20/09/17634382/g...
# 2   https://www.fool.com/investing/2020/09/23/is-g...
# 3   https://www.fool.com/investing/2020/09/23/goog...
# 4   https://seekingalpha.com/news/3616881-youtube-...
# ..                                                ...
# 61  https://www.nasdaq.com/articles/why-should-you...
# 62  https://www.nasdaq.com/articles/bluebird-brist...
# 63  https://www.nasdaq.com/articles/3-little-known...
# 64  https://www.reporter.am/walmart-is-using-drone...
# 65  https://bovnews.com/2020/09/23/reaping-the-rew...
#
# [66 rows x 4 columns]

# %%
data.iloc[1]["Link"]
# Out:
# 'https://www.benzinga.com/news/20/09/17634382/google-maps-adds-feature-to-identify-covid-19-hot-zones'
